# %%
import os
os.getcwd()
# Out:
# '/home/labsuser'

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np

# %%
os.chdir('/home/labsuser/Datasets')

# %%
import pandas as pd
Google_playstore = pd.read_csv('googleplaystore.csv')
Google_playstore
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
Google_playstore.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
Google_playstore.shape
# Out:
# (10841, 13)

# %%
Google_ps = Google_playstore.dropna()

# %%
Google_ps.shape
# Out:
# (9360, 13)

# %%
Google_ps.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
Google_ps['Size'] = Google_ps['Size'].replace(['Varies with device'],'0k')

# %%
Google_ps['Measure'] = Google_ps['Size'].str[-1]

# %%
Google_ps['Size']=Google_ps['Size'].replace({'M':'','k':'','K':''},regex=True)

# %%
Google_ps['Size']=Google_ps['Size'].astype(float)

# %%
Google_ps['Size'] = np.where(Google_ps['Measure'] =='M',Google_ps['Size']*1000,Google_ps['Size'])

# %%
Google_ps
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
Google_playstore2 = Google_ps.drop(['Measure'], axis=1)
Google_playstore2
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
Google_playstore2.Reviews = Google_playstore2.Reviews.astype('float')

# %%
Google_playstore2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9360 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9360 non-null   object
#  1   Category        9360 non-null   object
#  2   Rating          9360 non-null   float64
#  3   Reviews         9360 non-null   float64
#  4   Size            9360 non-null   float64
#  5   Installs        9360 non-null   object
#  6   Type            9360 non-null   object
#  7   Price           9360 non-null   object
#  8   Content Rating  9360 non-null   object
#  9   Genres          9360 non-null   object
#  10  Last Updated    9360 non-null   object
#  11  Current Ver     9360 non-null   object
#  12  Android Ver     9360 non-null   object
# dtypes: float64(3), object(10)
# memory usage: 1023.8+ KB

# %%
Google_playstore2['Installs'] = Google_playstore2['Installs'].str.replace('[, ,+]','')

# %%
Google_playstore2.Installs = Google_playstore2.Installs.astype('int')

# %%
Google_playstore2
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
Google_playstore2['Price'] = Google_playstore2.Price.str.replace('$','')
Google_playstore2
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
Google_playstore2.Price = Google_playstore2.Price.astype('float')

# %%
Google_playstore2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9360 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9360 non-null   object
#  1   Category        9360 non-null   object
#  2   Rating          9360 non-null   float64
#  3   Reviews         9360 non-null   float64
#  4   Size            9360 non-null   float64
#  5   Installs        9360 non-null   int64
#  6   Type            9360 non-null   object
#  7   Price           9360 non-null   float64
#  8   Content Rating  9360 non-null   object
#  9   Genres          9360 non-null   object
#  10  Last Updated    9360 non-null   object
#  11  Current Ver     9360 non-null   object
#  12  Android Ver     9360 non-null   object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 1023.8+ KB

# %%
Google_playstore2.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews     Size  Installs  Type  Price Content Rating  \
# 0     159.0  19000.0     10000  Free    0.0       Everyone
# 1     967.0  14000.0    500000  Free    0.0       Everyone
# 2   87510.0   8700.0   5000000  Free    0.0       Everyone
# 3  215644.0  25000.0  50000000  Free    0.0           Teen
# 4     967.0   2800.0    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
indexOut = Google_playstore2[(Google_playstore2['Rating']<0) & (Google_playstore2['Rating']>5)].index
Google_playstore2.drop(indexOut , inplace=True)
Google_playstore2
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
Google_playstore3 = Google_playstore2[(Google_playstore2.Reviews<=Google_playstore2.Installs)]
Google_playstore3
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
indexOut2 = Google_playstore3[(Google_playstore3['Price']>0) & (Google_playstore3['Type'] == 'Free')].index

# %%
Google_playstore3.drop(indexOut2, inplace=True)
Google_playstore3.shape
# Out:
# (9353, 13)

# %%
Google_playstore3
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.boxplot(Google_playstore3.Price)
plt.show()

# %%
# Are there any outliers? - YES

# %%
plt.boxplot(Google_playstore3.Reviews)
plt.show()

# %%
# Are there any apps with very high number of reviews? - YES 
# Do the values seem right? - NO

# %%
plt.hist(Google_playstore3.Rating)
plt.show()

# %%
# How are the ratings distributed? - Ratings are distributed to the right.
# Is it more toward higher ratings? - YES

# %%
#  1.Is 200 indeed a high price? - YES

# %%
Google_playstore3[Google_playstore3.Price>200]
# Out:
#                                  App   Category  Rating  Reviews     Size  \
# 4197          most expensive app (H)     FAMILY     4.3      6.0   1500.0
# 4362                      💎 I'm rich  LIFESTYLE     3.8    718.0  26000.0
# 4367        I'm Rich - Trump Edition  LIFESTYLE     3.6    275.0   7300.0
# 5351                       I am rich  LIFESTYLE     3.8   3547.0   1800.0
# 5354                  I am Rich Plus     FAMILY     4.0    856.0   8700.0
# 5355                   I am rich VIP  LIFESTYLE     3.8    411.0   2600.0
# 5356               I Am Rich Premium    FINANCE     4.1   1867.0   4700.0
# 5357             I am extremely Rich  LIFESTYLE     2.9     41.0   2900.0
# 5358                      I am Rich!    FINANCE     3.8     93.0  22000.0
# 5359              I am rich(premium)    FINANCE     3.5    472.0    965.0
# 5362                   I Am Rich Pro     FAMILY     4.4    201.0   2700.0
# 5364  I am rich (Most expensive app)    FINANCE     4.1    129.0   2700.0
# ...

# %%
Google_playstore4 = Google_playstore3[Google_playstore3.Price<200]
Google_playstore4
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
Google_playstore4.reset_index(drop=True)
# Out:
#                                                     App             Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                   Coloring book moana       ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint       ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                 ...                  ...
# 9333                                      FR Calculator               FAMILY
# 9334                                   Sya9a Maroc - FR               FAMILY
# 9335                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 9336                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 9337      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
Google_playstore4[Google_playstore4.Reviews>=2000000]
# Out:
#                                             App             Category  Rating  \
# 139                        Wattpad 📖 Free Books  BOOKS_AND_REFERENCE     4.6
# 335    Messenger – Text and Video Chat for Free        COMMUNICATION     4.0
# 336                          WhatsApp Messenger        COMMUNICATION     4.4
# 338                Google Chrome: Fast & Secure        COMMUNICATION     4.3
# 340                                       Gmail        COMMUNICATION     4.3
# ...                                         ...                  ...     ...
# 9166               Modern Combat 5: eSports FPS                 GAME     4.3
# 9841                               Google Earth     TRAVEL_AND_LOCAL     4.3
# 10186                          Farm Heroes Saga               FAMILY     4.4
# 10190                           Fallout Shelter               FAMILY     4.6
# 10327                          Garena Free Fire                 GAME     4.5
#
# ...

# %%
Google_playstore5 = Google_playstore4[Google_playstore3.Reviews<=2000000]
Google_playstore5.shape
# Out:
# (8885, 13)

# %%
 np.percentile( Google_playstore5.Installs,[10, 25, 50, 70, 90, 95, 99])
# Out:
# array([1.e+03, 1.e+04, 5.e+05, 1.e+06, 1.e+07, 1.e+07, 1.e+08])

# %%
 np.percentile( Google_playstore5.Installs,[10, 25, 50, 70, 90, 95, 99])[0]
# Out:
# 1000.0

# %%
np.percentile( Google_playstore5.Installs,[10, 25, 50, 70, 90, 95, 99])[6]
# Out:
# 100000000.0

# %%
indexOut3 = Google_playstore5[(Google_playstore5['Installs']<1000) & (Google_playstore5['Installs']>100000000)].index
Google_playstore5.drop(indexOut , inplace=True)
Google_playstore5
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
plt.scatter(y=Google_playstore5.Rating,x=Google_playstore5.Price)
plt.ylabel("Rating")
plt.xlabel("Price")
plt.show()

# %%
# What pattern do you observe? - While there is not a very clean pattern,it does look that the higher priced apps have better rating.Although,there are not a lot of apps which are high priced,but the pattern is present.
# Does rating increase with price? - Although, there are not a lot of apps which are high priced,but the pattern is apparent.

# %%
plt.scatter(y=Google_playstore5.Rating,x=Google_playstore5.Size)
plt.ylabel("Rating")
plt.xlabel("Size")
plt.show()

# %%
# Are heavier apps rated better? - Again,not a very clear pattern,but it does look like heavier apps are better rated.

# %%
plt.scatter(y=Google_playstore5.Rating,x=Google_playstore5.Reviews)
plt.ylabel("Rating")
plt.xlabel("Reviews")
plt.show()

# %%
# Does more review mean a better rating always? - YES

# %%
Google_playstore5.rename({'Content Rating':'Content_Rating'}, axis=1, inplace=True)

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8.27))
sns.boxplot(x=Google_playstore5.Content_Rating,y=Google_playstore5.Rating)
# Out:
# <AxesSubplot:xlabel='Content_Rating', ylabel='Rating'>

# %%
# Is there any difference in the ratings? Are some types liked better? - While the median rating for most others is similar, the rating for "Adults Only 18+" is the highest.

# %%
plt.figure(figsize=(25,8.27))
sns.boxplot(Google_playstore5.Category,Google_playstore5.Rating)
plt.xticks(fontsize=18,rotation='vertical')
plt.yticks(fontsize=18)
plt.xlabel("Category", fontsize=20)
plt.ylabel("Rating", fontsize=20)
# Out:
# Text(0, 0.5, 'Rating')

# %%
# Which genre has the best ratings? - Apps around Health & Fitness,Books and Reference,Events seem to have the highest median ratings.

# %%
inp1 = Google_playstore5

# %%
import numpy as np
inp1['Reviews'] = np.log1p(inp1.Reviews)
inp1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
inp1['Installs'] = np.log1p(inp1.Installs)
inp1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
inp1.drop(["App","Last Updated","Current Ver","Android Ver"],inplace=True,axis=1)

# %%
inp1
# Out:
#                   Category  Rating    Reviews     Size   Installs  Type  \
# 0           ART_AND_DESIGN     4.1   5.075174  19000.0   9.210440  Free
# 1           ART_AND_DESIGN     3.9   6.875232  14000.0  13.122365  Free
# 2           ART_AND_DESIGN     4.7  11.379520   8700.0  15.424949  Free
# 3           ART_AND_DESIGN     4.5  12.281389  25000.0  17.727534  Free
# 4           ART_AND_DESIGN     4.3   6.875232   2800.0  11.512935  Free
# ...                    ...     ...        ...      ...        ...   ...
# 10834               FAMILY     4.0   2.079442   2600.0   6.216606  Free
# 10836               FAMILY     4.5   3.663562  53000.0   8.517393  Free
# 10837               FAMILY     5.0   1.609438   3600.0   4.615121  Free
# 10839  BOOKS_AND_REFERENCE     4.5   4.744932      0.0   6.908755  Free
# 10840            LIFESTYLE     4.5  12.894981  19000.0  16.118096  Free
#
#        Price Content_Rating                     Genres
# ...

# %%
inp2 = pd.get_dummies(inp1,prefix_sep='_',columns=['Category', 'Genres','Content_Rating','Type'])
inp2
# Out:
#        Rating    Reviews     Size   Installs  Price  Category_ART_AND_DESIGN  \
# 0         4.1   5.075174  19000.0   9.210440    0.0                        1
# 1         3.9   6.875232  14000.0  13.122365    0.0                        1
# 2         4.7  11.379520   8700.0  15.424949    0.0                        1
# 3         4.5  12.281389  25000.0  17.727534    0.0                        1
# 4         4.3   6.875232   2800.0  11.512935    0.0                        1
# ...       ...        ...      ...        ...    ...                      ...
# 10834     4.0   2.079442   2600.0   6.216606    0.0                        0
# 10836     4.5   3.663562  53000.0   8.517393    0.0                        0
# 10837     5.0   1.609438   3600.0   4.615121    0.0                        0
# 10839     4.5   4.744932      0.0   6.908755    0.0                        0
# 10840     4.5  12.894981  19000.0  16.118096    0.0                        0
#
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
linreg=LinearRegression()
from statsmodels.api import OLS
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as ms

# %%
X=inp2.iloc[:,1:]
y=inp2.iloc[:,:1]
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.30, random_state=1)
X_train.shape,X_test.shape
# Out:
# ((6219, 160), (2666, 160))

# %%
Model=linreg.fit(X_train, y_train)
predict=linreg.predict(X_test)

y_test=np.array(y_test)
predict=np.array(predict)

a=pd.DataFrame({'Actual':y_test.flatten(),'Predicted':predict.flatten()});a.head(10)
# Out:
#    Actual  Predicted
# 0     4.4   4.083766
# 1     5.0   4.258102
# 2     3.0   3.867149
# 3     4.8   4.639972
# 4     4.6   4.006927
# 5     4.5   4.454361
# 6     4.4   4.185329
# 7     4.4   4.594785
# 8     4.1   4.156933
# 9     4.5   4.583615

# %%
fig=a.head(25)
fig.plot(kind='bar',figsize=(10,8))
# Out:
# <AxesSubplot:>

# %%
results=OLS( y_train,X_train).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Rating   R-squared:                       0.168
# Model:                            OLS   Adj. R-squared:                  0.151
# Method:                 Least Squares   F-statistic:                     9.978
# Date:                Sat, 25 Sep 2021   Prob (F-statistic):          3.40e-162
# Time:                        12:18:50   Log-Likelihood:                -4187.4
# No. Observations:                6219   AIC:                             8623.
# Df Residuals:                    6095   BIC:                             9458.
# Df Model:                         123
# Covariance Type:            nonrobust
# ...
#                                                    coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# ...

# %%
print('R2_Score=',r2_score(y_test,predict))
print('Root Mean Squared Error=',np.sqrt(ms(y_test,predict)))
print('Prediction Error Percentage is',round((0.50/np.mean(y_test))*100))
# Out:
# R2_Score= 0.12769928762060412
# Root Mean Squared Error= 0.4978429837003729
# Prediction Error Percentage is 12.0
